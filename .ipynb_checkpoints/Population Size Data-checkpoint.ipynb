# %%
import pandas as pd
from sqlalchemy import create_engine
from config import key

# %%
pop_file = "/Users/shifaamian/Documents/GitHub/Earthquake_Project/worldcitiespop.csv"
pop_df = pd.read_csv(pop_file)
pop_df.head()
# Out:
#   Country        City  AccentCity Region  Population   Latitude  Longitude
# 0      ad       aixas       Aixàs      6         NaN  42.483333   1.466667
# 1      ad  aixirivali  Aixirivali      6         NaN  42.466667   1.500000
# 2      ad  aixirivall  Aixirivall      6         NaN  42.466667   1.500000
# 3      ad   aixirvall   Aixirvall      6         NaN  42.466667   1.500000
# 4      ad    aixovall    Aixovall      6         NaN  42.466667   1.483333

# %%
# Create a filtered dataframe from specific columns
pop_cols = ["Country", "City", "Population"]
pop_transformed = pop_df[pop_cols].copy()

# Rename the column headers
pop_transformed = pop_transformed.rename(columns={"Country": "country_code",
                                                          "City": "city_name",
                                                          "Popultation": "population_size"})

# Clean the data by dropping duplicates and setting the index
pop_transformed.drop_duplicates("country_code", inplace=True)
pop_transformed.set_index("country_code", inplace=True)

pop_transformed.head()
# Out:
#                         city_name  Population
# country_code
# ad                          aixas         NaN
# ae                       abu dabi         NaN
# af            `aaqadari yosufkhel         NaN
# ag                       aberdeen         NaN
# ai                         bethel         NaN

# %%
connection_string = "postgres:postgres@localhost:5432/earthquakes_db"


engine = create_engine(f"postgresql://postgres:root123@localhost:5432/earthquakes_db")

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# //anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
pop_transformed.to_sql(name='pop', con=engine, if_exists='append', index=True)
