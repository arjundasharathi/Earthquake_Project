# %% [markdown]
# # Earthquake API Call

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from sqlalchemy import create_engine
from config import key
from datetime import datetime
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Extract data from API
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1819-01-01&endtime=2019-12-02&minmagnitude=6'
earthquakes = requests.get(url).json()

# %%
allearthquakes = earthquakes['features']
#turn data into a dataframe
earthquakerawdata = pd.DataFrame(allearthquakes)
earthquakerawdata.count()
# Out:
# type          11621
# properties    11621
# geometry      11621
# id            11621
# dtype: int64

# %%
# Preview data for first earthquake
allearthquakes[0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 6,
#   'place': '41km NW of Platanos, Greece',
#   'time': 1574839422552,
#   'updated': 1575415107456,
#   'tz': 120,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006dlt',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006dlt&format=geojson',
#   'felt': 108,
#   'cdi': 5.7,
#   'mmi': 4.462,
#   'alert': 'green',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 615,
#   'net': 'us',
#   'code': '70006dlt',
#   'ids': ',us70006dlt,',
#   'sources': ',us,',
#   'types': ',dyfi,geoserve,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#   'nst': None,
#   'dmin': 1.394,
#   'rms': 1.16,
#   'gap': 23,
#   'magType': 'mww',
#   'type': 'earthquake',
#   'title': 'M 6.0 - 41km NW of Platanos, Greece'},
#  'geometry': {'type': 'Point', 'coordinates': [23.2673, 35.7272, 71.76]},
#  'id': 'us70006dlt'}

# %%
# Loop through json file and save data in a list of dictionaries

allearthquake_features = []

for i in range(len(allearthquakes)):
    mag = allearthquakes[i]["properties"]["mag"]
    place = allearthquakes[i]["properties"]["place"]
    timestamp = allearthquakes[i]["properties"]["time"]
    tsunami = allearthquakes[i]["properties"]["tsunami"]
    eq_lat = allearthquakes[i]["geometry"]["coordinates"][0]
    eq_lon = allearthquakes[i]["geometry"]["coordinates"][1]
    city_name = citipy.nearest_city(eq_lon,eq_lat).city_name
    country_code = citipy.nearest_city(eq_lon,eq_lat).country_code

    earthquake_info = {"mag":mag,
    "place":place,
    "timestamp":timestamp,
    "tsunami":tsunami,
    "eq_lon":eq_lon,
    "eq_lat":eq_lat,
    "city_name":city_name,
    "country_code":country_code}
    
    allearthquake_features.append(earthquake_info)
    
allearthquake_features
# Out:
# [{'mag': 6,
#   'place': '41km NW of Platanos, Greece',
#   'timestamp': 1574839422552,
#   'tsunami': 0,
#   'eq_lon': 35.7272,
#   'eq_lat': 23.2673,
#   'city_name': 'platanos',
#   'country_code': 'gr'},
#  {'mag': 6.4,
#   'place': '16km WNW of Fushe-Kruje, Albania',
#   'timestamp': 1574736852598,
#   'tsunami': 0,
#   'eq_lon': 41.5109,
#   'eq_lat': 19.5218,
#   'city_name': 'shijak',
#   'country_code': 'al'},
#  {'mag': 6.3,
#   'place': '96km SE of Adak, Alaska',
#   'timestamp': 1574556841052,
#   'tsunami': 1,
#   'eq_lon': 51.3809,
#   'eq_lat': -175.5108,
#   'city_name': 'provideniya',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': 'Papua region, Indonesia',
#   'timestamp': 1574511076261,
#   'tsunami': 1,
#   'eq_lon': 1.6286,
#   'eq_lat': 132.7854,
#   'city_name': 'manokwari',
#   'country_code': 'id'},
#  {'mag': 6.2,
#   'place': '32km ESE of Chaloem Phra Kiat, Thailand',
#   'timestamp': 1574293843955,
#   'tsunami': 0,
#   'eq_lon': 19.4533,
#   'eq_lat': 101.3558,
#   'city_name': 'chiang klang',
#   'country_code': 'th'},
#  {'mag': 6.3,
#   'place': '267km NW of Ozernovskiy, Russia',
#   'timestamp': 1574238367542,
#   'tsunami': 0,
#   'eq_lon': 53.1633,
#   'eq_lat': 153.6852,
#   'city_name': 'sobolevo',
#   'country_code': 'ru'},
#  {'mag': 6.3,
#   'place': '125km SW of Puerto Madero, Mexico',
#   'timestamp': 1574224025120,
#   'tsunami': 0,
#   'eq_lon': 13.8855,
#   'eq_lat': -93.2133,
#   'city_name': 'puerto madero',
#   'country_code': 'mx'},
#  {'mag': 6,
#   'place': '136km NW of Kota Ternate, Indonesia',
#   'timestamp': 1573765974750,
#   'tsunami': 0,
#   'eq_lon': 1.5673,
#   'eq_lat': 126.4136,
#   'city_name': 'bitung',
#   'country_code': 'id'},
#  {'mag': 7.1,
#   'place': '138km E of Bitung, Indonesia',
#   'timestamp': 1573748260582,
#   'tsunami': 1,
#   'eq_lon': 1.6199,
#   'eq_lat': 126.414,
#   'city_name': 'bitung',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': '146km NW of Pangai, Tonga',
#   'timestamp': 1573513408056,
#   'tsunami': 0,
#   'eq_lon': -18.8857,
#   'eq_lat': -175.3598,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6.5,
#   'place': '166km SSW of Ndoi Island, Fiji',
#   'timestamp': 1573209884338,
#   'tsunami': 0,
#   'eq_lon': -21.9449,
#   'eq_lat': -179.5113,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6,
#   'place': '33km ENE of Sola, Vanuatu',
#   'timestamp': 1573000749303,
#   'tsunami': 0,
#   'eq_lon': -13.7208,
#   'eq_lat': 167.8086,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6,
#   'place': '23km ENE of Sola, Vanuatu',
#   'timestamp': 1572995846588,
#   'tsunami': 0,
#   'eq_lon': -13.7988,
#   'eq_lat': 167.7494,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6.3,
#   'place': 'East of the South Sandwich Islands',
#   'timestamp': 1572987121485,
#   'tsunami': 0,
#   'eq_lon': -57.9236,
#   'eq_lat': -9.3217,
#   'city_name': 'cape town',
#   'country_code': 'za'},
#  {'mag': 6.6,
#   'place': '136km W of Neiafu, Tonga',
#   'timestamp': 1572907412280,
#   'tsunami': 1,
#   'eq_lon': -18.5747,
#   'eq_lat': -175.272,
#   'city_name': 'neiafu',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '30km SW of Illapel, Chile',
#   'timestamp': 1572904405320,
#   'tsunami': 0,
#   'eq_lon': -31.8362,
#   'eq_lat': -71.3753,
#   'city_name': 'illapel',
#   'country_code': 'cl'},
#  {'mag': 6.1,
#   'place': '122km NNE of Visokoi Island, South Georgia and the South Sandwich Islands',
#   'timestamp': 1572718121113,
#   'tsunami': 0,
#   'eq_lon': -55.735,
#   'eq_lat': -26.2399,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.5,
#   'place': '2km E of Bulatukan, Philippines',
#   'timestamp': 1572484279100,
#   'tsunami': 1,
#   'eq_lon': 6.905,
#   'eq_lat': 125.1873,
#   'city_name': 'bulatukan',
#   'country_code': 'ph'},
#  {'mag': 6.6,
#   'place': '8km NE of Columbio, Philippines',
#   'timestamp': 1572311083874,
#   'tsunami': 1,
#   'eq_lon': 6.7544,
#   'eq_lat': 124.9852,
#   'city_name': 'columbio',
#   'country_code': 'ph'},
#  {'mag': 6.3,
#   'place': 'North of Ascension Island',
#   'timestamp': 1571846894497,
#   'tsunami': 1,
#   'eq_lon': -1.0987,
#   'eq_lat': -13.8367,
#   'city_name': 'georgetown',
#   'country_code': 'sh'},
#  {'mag': 6.4,
#   'place': '63km NNE of Isangel, Vanuatu',
#   'timestamp': 1571626349674,
#   'tsunami': 0,
#   'eq_lon': -19.0184,
#   'eq_lat': 169.4883,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6.4,
#   'place': '8km ENE of Columbio, Philippines',
#   'timestamp': 1571225826294,
#   'tsunami': 1,
#   'eq_lon': 6.7139,
#   'eq_lat': 125.0088,
#   'city_name': 'columbio',
#   'country_code': 'ph'},
#  {'mag': 6,
#   'place': 'Southern East Pacific Rise',
#   'timestamp': 1569902167115,
#   'tsunami': 0,
#   'eq_lon': -55.9278,
#   'eq_lat': -122.5586,
#   'city_name': 'rikitea',
#   'country_code': 'pf'},
#  {'mag': 6.7,
#   'place': '69km WSW of Constitucion, Chile',
#   'timestamp': 1569772673236,
#   'tsunami': 1,
#   'eq_lon': -35.4758,
#   'eq_lat': -73.163,
#   'city_name': 'constitucion',
#   'country_code': 'cl'},
#  {'mag': 6.2,
#   'place': '85km SSE of Pondaguitan, Philippines',
#   'timestamp': 1569722571934,
#   'tsunami': 0,
#   'eq_lon': 5.6856,
#   'eq_lat': 126.5465,
#   'city_name': 'pundaguitan',
#   'country_code': 'ph'},
#  {'mag': 6.1,
#   'place': '100km S of Raoul Island, New Zealand',
#   'timestamp': 1569585902549,
#   'tsunami': 0,
#   'eq_lon': -30.1733,
#   'eq_lat': -177.8625,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '30km WSW of Villa La Angostura, Argentina',
#   'timestamp': 1569515778155,
#   'tsunami': 0,
#   'eq_lon': -40.8145,
#   'eq_lat': -71.9993,
#   'city_name': 'san carlos de bariloche',
#   'country_code': 'ar'},
#  {'mag': 6.5,
#   'place': '11km S of Kairatu, Indonesia',
#   'timestamp': 1569455203543,
#   'tsunami': 1,
#   'eq_lon': -3.4528,
#   'eq_lat': 128.3699,
#   'city_name': 'ambon',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': 'Southwest Indian Ridge',
#   'timestamp': 1569359987423,
#   'tsunami': 0,
#   'eq_lon': -33.8212,
#   'eq_lat': 56.2997,
#   'city_name': 'saint-joseph',
#   'country_code': 're'},
#  {'mag': 6,
#   'place': '69km NNW of San Antonio, Puerto Rico',
#   'timestamp': 1569295420000,
#   'tsunami': 1,
#   'eq_lon': 19.077,
#   'eq_lat': -67.2701,
#   'city_name': 'isabela',
#   'country_code': 'us'},
#  {'mag': 6.1,
#   'place': '70km NNE of Blimbing, Indonesia',
#   'timestamp': 1568876793291,
#   'tsunami': 1,
#   'eq_lon': -6.0708,
#   'eq_lat': 111.8422,
#   'city_name': 'lasem',
#   'country_code': 'id'},
#  {'mag': 6.6,
#   'place': '34km NNE of Ndoi Island, Fiji',
#   'timestamp': 1567353260392,
#   'tsunami': 1,
#   'eq_lon': -20.3641,
#   'eq_lat': -178.5701,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.3,
#   'place': '285km W of Bandon, Oregon',
#   'timestamp': 1567091278646,
#   'tsunami': 1,
#   'eq_lon': 43.5425,
#   'eq_lat': -127.8817,
#   'city_name': 'north bend',
#   'country_code': 'us'},
#  {'mag': 6.6,
#   'place': '131km S of Bristol Island, South Sandwich Islands',
#   'timestamp': 1566950119187,
#   'tsunami': 1,
#   'eq_lon': -60.2152,
#   'eq_lat': -26.5801,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6,
#   'place': '61km SW of Sola, Vanuatu',
#   'timestamp': 1566661887119,
#   'tsunami': 0,
#   'eq_lon': -14.309,
#   'eq_lat': 167.1897,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6,
#   'place': 'Western Indian-Antarctic Ridge',
#   'timestamp': 1566397705652,
#   'tsunami': 0,
#   'eq_lon': -50.3302,
#   'eq_lat': 139.324,
#   'city_name': 'new norfolk',
#   'country_code': 'au'},
#  {'mag': 6,
#   'place': '87km SE of Lata, Solomon Islands',
#   'timestamp': 1566306232633,
#   'tsunami': 0,
#   'eq_lon': -11.3683,
#   'eq_lat': 166.2912,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.3,
#   'place': '61km ENE of Namie, Japan',
#   'timestamp': 1564914183726,
#   'tsunami': 0,
#   'eq_lon': 37.7594,
#   'eq_lat': 141.6031,
#   'city_name': 'namie',
#   'country_code': 'jp'},
#  {'mag': 6.9,
#   'place': '106km WSW of Tugu Hilir, Indonesia',
#   'timestamp': 1564747407001,
#   'tsunami': 1,
#   'eq_lon': -7.2822,
#   'eq_lat': 104.7907,
#   'city_name': 'labuhan',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': 'Southern East Pacific Rise',
#   'timestamp': 1564725055239,
#   'tsunami': 0,
#   'eq_lon': -49.7307,
#   'eq_lat': -113.8331,
#   'city_name': 'rikitea',
#   'country_code': 'pf'},
#  {'mag': 6.8,
#   'place': '95km SW of San Antonio, Chile',
#   'timestamp': 1564684087270,
#   'tsunami': 1,
#   'eq_lon': -34.2364,
#   'eq_lat': -72.3102,
#   'city_name': 'san antonio',
#   'country_code': 'cl'},
#  {'mag': 6.6,
#   'place': '62km E of Lakatoro, Vanuatu',
#   'timestamp': 1564585353853,
#   'tsunami': 1,
#   'eq_lon': -16.1985,
#   'eq_lat': 167.9982,
#   'city_name': 'lakatoro',
#   'country_code': 'vu'},
#  {'mag': 6.3,
#   'place': '138km ESE of Shingu, Japan',
#   'timestamp': 1564252267540,
#   'tsunami': 0,
#   'eq_lon': 33.1492,
#   'eq_lat': 137.3029,
#   'city_name': 'kumano',
#   'country_code': 'jp'},
#  {'mag': 6,
#   'place': '14km ENE of Itbayat, Philippines',
#   'timestamp': 1564184278444,
#   'tsunami': 0,
#   'eq_lon': 20.8373,
#   'eq_lat': 121.9744,
#   'city_name': 'basco',
#   'country_code': 'ph'},
#  {'mag': 6,
#   'place': 'Balleny Islands region',
#   'timestamp': 1563878004050,
#   'tsunami': 0,
#   'eq_lon': -61.2867,
#   'eq_lat': 154.1145,
#   'city_name': 'hobart',
#   'country_code': 'au'},
#  {'mag': 6.3,
#   'place': '28km NNW of Kandrian, Papua New Guinea',
#   'timestamp': 1563178894171,
#   'tsunami': 1,
#   'eq_lon': -5.9707,
#   'eq_lat': 149.4881,
#   'city_name': 'kandrian',
#   'country_code': 'pg'},
#  {'mag': 7.2,
#   'place': '93km NNE of Laiwui, Indonesia',
#   'timestamp': 1563095451523,
#   'tsunami': 1,
#   'eq_lon': -0.5858,
#   'eq_lat': 128.034,
#   'city_name': 'tidore',
#   'country_code': 'id'},
#  {'mag': 6.6,
#   'place': '200km W of Broome, Australia',
#   'timestamp': 1563082763420,
#   'tsunami': 0,
#   'eq_lon': -18.2242,
#   'eq_lat': 120.3584,
#   'city_name': 'broome',
#   'country_code': 'au'},
#  {'mag': 6.1,
#   'place': '169km NW of Naze, Japan',
#   'timestamp': 1562979464339,
#   'tsunami': 0,
#   'eq_lon': 29.3533,
#   'eq_lat': 128.1534,
#   'city_name': 'naze',
#   'country_code': 'jp'},
#  {'mag': 6,
#   'place': '177km N of Arawa, Papua New Guinea',
#   'timestamp': 1562864917977,
#   'tsunami': 1,
#   'eq_lon': -4.6408,
#   'eq_lat': 155.2241,
#   'city_name': 'arawa',
#   'country_code': 'pg'},
#  {'mag': 6.9,
#   'place': '134km WSW of Kota Ternate, Indonesia',
#   'timestamp': 1562512120525,
#   'tsunami': 0,
#   'eq_lon': 0.5126,
#   'eq_lat': 126.1892,
#   'city_name': 'ternate',
#   'country_code': 'id'},
#  {'mag': 7.1,
#   'place': '2019 Ridgecrest Earthquake Sequence',
#   'timestamp': 1562383193040,
#   'tsunami': 1,
#   'eq_lon': 35.7695,
#   'eq_lat': -117.5993333,
#   'city_name': 'ridgecrest',
#   'country_code': 'us'},
#  {'mag': 6.4,
#   'place': 'Ridgecrest Earthquake Sequence',
#   'timestamp': 1562261629000,
#   'tsunami': 1,
#   'eq_lon': 35.7053333,
#   'eq_lat': -117.5038333,
#   'city_name': 'ridgecrest',
#   'country_code': 'us'},
#  {'mag': 6.2,
#   'place': '194km WSW of Bella Bella, Canada',
#   'timestamp': 1562214644424,
#   'tsunami': 1,
#   'eq_lon': 51.2369,
#   'eq_lat': -130.5005,
#   'city_name': 'port hardy',
#   'country_code': 'ca'},
#  {'mag': 6,
#   'place': '40km ENE of Luganville, Vanuatu',
#   'timestamp': 1562001208400,
#   'tsunami': 0,
#   'eq_lon': -15.4403,
#   'eq_lat': 167.531,
#   'city_name': 'luganville',
#   'country_code': 'vu'},
#  {'mag': 6.4,
#   'place': '95km SW of Farallon de Pajaros, Northern Mariana Islands',
#   'timestamp': 1561737091302,
#   'tsunami': 1,
#   'eq_lon': 19.8515,
#   'eq_lat': 144.3477,
#   'city_name': 'shimoda',
#   'country_code': 'jp'},
#  {'mag': 6.3,
#   'place': "118km NNW of L'Esperance Rock, New Zealand",
#   'timestamp': 1561633496341,
#   'tsunami': 0,
#   'eq_lon': -30.3961,
#   'eq_lat': -179.182,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.2,
#   'place': '5km ESE of Aserrio de Gariche, Panama',
#   'timestamp': 1561526631514,
#   'tsunami': 0,
#   'eq_lon': 8.4612,
#   'eq_lat': -82.754,
#   'city_name': 'gariche',
#   'country_code': 'pa'},
#  {'mag': 6.3,
#   'place': "100km E of Ust'-Kamchatsk Staryy, Russia",
#   'timestamp': 1561515487841,
#   'tsunami': 0,
#   'eq_lon': 56.1821,
#   'eq_lat': 164.0881,
#   'city_name': 'ust-kamchatsk',
#   'country_code': 'ru'},
#  {'mag': 6.4,
#   'place': "108km E of Ust'-Kamchatsk Staryy, Russia",
#   'timestamp': 1561453540478,
#   'tsunami': 1,
#   'eq_lon': 56.202,
#   'eq_lat': 164.2327,
#   'city_name': 'ust-kamchatsk',
#   'country_code': 'ru'},
#  {'mag': 7.3,
#   'place': '292km NW of Saumlaki, Indonesia',
#   'timestamp': 1561344819830,
#   'tsunami': 1,
#   'eq_lon': -6.4078,
#   'eq_lat': 129.1692,
#   'city_name': 'ambon',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': '224km W of Abepura, Indonesia',
#   'timestamp': 1561338329464,
#   'tsunami': 1,
#   'eq_lon': -2.7756,
#   'eq_lat': 138.5675,
#   'city_name': 'vanimo',
#   'country_code': 'pg'},
#  {'mag': 6.2,
#   'place': "150km ENE of L'Esperance Rock, New Zealand",
#   'timestamp': 1561106236948,
#   'tsunami': 0,
#   'eq_lon': -30.8591,
#   'eq_lat': -177.4681,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.3,
#   'place': '239km W of Abepura, Indonesia',
#   'timestamp': 1560965088803,
#   'tsunami': 1,
#   'eq_lon': -2.2656,
#   'eq_lat': 138.461,
#   'city_name': 'biak',
#   'country_code': 'id'},
#  {'mag': 6.4,
#   'place': '139km S of Raoul Island, New Zealand',
#   'timestamp': 1560927705433,
#   'tsunami': 1,
#   'eq_lon': -30.5243,
#   'eq_lat': -177.8482,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.4,
#   'place': '31km WSW of Tsuruoka, Japan',
#   'timestamp': 1560864139010,
#   'tsunami': 1,
#   'eq_lon': 38.6391,
#   'eq_lat': 139.4769,
#   'city_name': 'tsuruoka',
#   'country_code': 'jp'},
#  {'mag': 6.1,
#   'place': "150km ENE of L'Esperance Rock, New Zealand",
#   'timestamp': 1560751324099,
#   'tsunami': 0,
#   'eq_lon': -30.8389,
#   'eq_lat': -177.481,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.3,
#   'place': "91km ENE of L'Esperance Rock, New Zealand",
#   'timestamp': 1560662234868,
#   'tsunami': 1,
#   'eq_lon': -31.0004,
#   'eq_lat': -178.0819,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 7.3,
#   'place': "116km NE of L'Esperance Rock, New Zealand",
#   'timestamp': 1560639304130,
#   'tsunami': 1,
#   'eq_lon': -30.6441,
#   'eq_lat': -178.0995,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '82km ENE of `Ohonua, Tonga',
#   'timestamp': 1560635770835,
#   'tsunami': 0,
#   'eq_lon': -21.1807,
#   'eq_lat': -174.169,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.4,
#   'place': '72km W of Coquimbo, Chile',
#   'timestamp': 1560471552401,
#   'tsunami': 0,
#   'eq_lon': -30.0557,
#   'eq_lat': -72.0819,
#   'city_name': 'coquimbo',
#   'country_code': 'cl'},
#  {'mag': 6.4,
#   'place': 'Izu Islands, Japan region',
#   'timestamp': 1559623156961,
#   'tsunami': 0,
#   'eq_lon': 29.0665,
#   'eq_lat': 139.289,
#   'city_name': 'shimoda',
#   'country_code': 'jp'},
#  {'mag': 6,
#   'place': '108km E of `Ohonua, Tonga',
#   'timestamp': 1559471789673,
#   'tsunami': 0,
#   'eq_lon': -21.2068,
#   'eq_lat': -173.9096,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '34km ESE of Pondaguitan, Philippines',
#   'timestamp': 1559297552876,
#   'tsunami': 0,
#   'eq_lon': 6.2795,
#   'eq_lat': 126.479,
#   'city_name': 'pundaguitan',
#   'country_code': 'ph'},
#  {'mag': 6,
#   'place': '131km WSW of Vaini, Tonga',
#   'timestamp': 1559230681451,
#   'tsunami': 0,
#   'eq_lon': -21.7541,
#   'eq_lat': -176.3171,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.6,
#   'place': '32km S of La Libertad, El Salvador',
#   'timestamp': 1559207012337,
#   'tsunami': 1,
#   'eq_lon': 13.1994,
#   'eq_lat': -89.3056,
#   'city_name': 'la libertad',
#   'country_code': 'sv'},
#  {'mag': 8,
#   'place': '78km SE of Lagunas, Peru',
#   'timestamp': 1558856475073,
#   'tsunami': 1,
#   'eq_lon': -5.8119,
#   'eq_lat': -75.2697,
#   'city_name': 'lagunas',
#   'country_code': 'pe'},
#  {'mag': 6,
#   'place': '60km E of Amatignak Island, Alaska',
#   'timestamp': 1558601117746,
#   'tsunami': 1,
#   'eq_lon': 51.3078,
#   'eq_lat': -178.2387,
#   'city_name': 'provideniya',
#   'country_code': 'ru'},
#  {'mag': 6.3,
#   'place': '164km E of Tadine, New Caledonia',
#   'timestamp': 1558277810691,
#   'tsunami': 1,
#   'eq_lon': -21.6074,
#   'eq_lat': 169.4692,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6,
#   'place': '176km E of Tadine, New Caledonia',
#   'timestamp': 1558276031826,
#   'tsunami': 0,
#   'eq_lon': -21.7313,
#   'eq_lat': 169.5758,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.3,
#   'place': '196km E of Tadine, New Caledonia',
#   'timestamp': 1558229009151,
#   'tsunami': 1,
#   'eq_lon': -21.6619,
#   'eq_lat': 169.7779,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 7.6,
#   'place': '46km SSE of Namatanai, Papua New Guinea',
#   'timestamp': 1557838705939,
#   'tsunami': 1,
#   'eq_lon': -4.051,
#   'eq_lat': 152.5967,
#   'city_name': 'namatanai',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '10km N of Canoas, Costa Rica',
#   'timestamp': 1557689090373,
#   'tsunami': 0,
#   'eq_lon': 8.625,
#   'eq_lat': -82.8298,
#   'city_name': 'celmira',
#   'country_code': 'pa'},
#  {'mag': 6.2,
#   'place': '42km ESE of Miyazaki-shi, Japan',
#   'timestamp': 1557445722779,
#   'tsunami': 0,
#   'eq_lon': 31.7772,
#   'eq_lat': 131.8483,
#   'city_name': 'shintomi',
#   'country_code': 'jp'},
#  {'mag': 7.1,
#   'place': '33km NW of Bulolo, Papua New Guinea',
#   'timestamp': 1557177577983,
#   'tsunami': 1,
#   'eq_lon': -6.9746,
#   'eq_lat': 146.4494,
#   'city_name': 'bulolo',
#   'country_code': 'pg'},
#  {'mag': 6.2,
#   'place': '144km NNE of Buala, Solomon Islands',
#   'timestamp': 1556868331787,
#   'tsunami': 0,
#   'eq_lon': -6.9478,
#   'eq_lat': 160.1125,
#   'city_name': 'buala',
#   'country_code': 'sb'},
#  {'mag': 6.3,
#   'place': 'Carlsberg Ridge',
#   'timestamp': 1556547592499,
#   'tsunami': 0,
#   'eq_lon': 10.8649,
#   'eq_lat': 57.2283,
#   'city_name': 'bargal',
#   'country_code': 'so'},
#  {'mag': 6,
#   'place': 'South of the Fiji Islands',
#   'timestamp': 1556029217830,
#   'tsunami': 0,
#   'eq_lon': -24.7059,
#   'eq_lat': -178.7639,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.4,
#   'place': '17km ESE of Tutubigan, Philippines',
#   'timestamp': 1555997873147,
#   'tsunami': 1,
#   'eq_lon': 11.7547,
#   'eq_lat': 125.2013,
#   'city_name': 'tutubigan',
#   'country_code': 'ph'},
#  {'mag': 6,
#   'place': '49km N of Visokoi Island, South Georgia and the South Sandwich Islands',
#   'timestamp': 1555944545341,
#   'tsunami': 0,
#   'eq_lon': -56.2633,
#   'eq_lat': -27.3509,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.1,
#   'place': '3km SSW of Floridablanca, Philippines',
#   'timestamp': 1555924272013,
#   'tsunami': 0,
#   'eq_lon': 14.9538,
#   'eq_lat': 120.5149,
#   'city_name': 'gutad',
#   'country_code': 'ph'},
#  {'mag': 6.3,
#   'place': 'Western Indian-Antarctic Ridge',
#   'timestamp': 1555598761733,
#   'tsunami': 0,
#   'eq_lon': -51.127,
#   'eq_lat': 139.321,
#   'city_name': 'new norfolk',
#   'country_code': 'au'},
#  {'mag': 6.1,
#   'place': '8km NE of Hualian, Taiwan',
#   'timestamp': 1555563666493,
#   'tsunami': 0,
#   'eq_lon': 24.0374,
#   'eq_lat': 121.6501,
#   'city_name': 'suao',
#   'country_code': 'tw'},
#  {'mag': 6,
#   'place': '94km WSW of Kandrian, Papua New Guinea',
#   'timestamp': 1555080691603,
#   'tsunami': 1,
#   'eq_lon': -6.4883,
#   'eq_lat': 148.7394,
#   'city_name': 'kandrian',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '116km ENE of Hihifo, Tonga',
#   'timestamp': 1555071784870,
#   'tsunami': 0,
#   'eq_lon': -15.4067,
#   'eq_lat': -172.8171,
#   'city_name': 'hihifo',
#   'country_code': 'to'},
#  {'mag': 6.8,
#   'place': '98km SSW of Luwuk, Indonesia',
#   'timestamp': 1555069249363,
#   'tsunami': 1,
#   'eq_lon': -1.8146,
#   'eq_lat': 122.5798,
#   'city_name': 'luwuk',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': '143km NE of Miyako, Japan',
#   'timestamp': 1554970701380,
#   'tsunami': 0,
#   'eq_lon': 40.4096,
#   'eq_lat': 143.2985,
#   'city_name': 'miyako',
#   'country_code': 'jp'},
#  {'mag': 6.5,
#   'place': '83km ENE of Bristol Island, South Sandwich Islands',
#   'timestamp': 1554832438423,
#   'tsunami': 1,
#   'eq_lon': -58.6262,
#   'eq_lat': -25.304,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.3,
#   'place': '200km NNW of Dili, East Timor',
#   'timestamp': 1554587701660,
#   'tsunami': 0,
#   'eq_lon': -6.8285,
#   'eq_lat': 125.0416,
#   'city_name': 'atambua',
#   'country_code': 'id'},
#  {'mag': 6.4,
#   'place': '94km NNW of Visokoi Island, South Georgia and the South Sandwich Islands',
#   'timestamp': 1554480856716,
#   'tsunami': 1,
#   'eq_lon': -55.9308,
#   'eq_lat': -27.8522,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.4,
#   'place': '32km ENE of Kiska Volcano, Alaska',
#   'timestamp': 1554240930049,
#   'tsunami': 1,
#   'eq_lon': 52.1702,
#   'eq_lat': 178.0709,
#   'city_name': 'beringovskiy',
#   'country_code': 'ru'},
#  {'mag': 6,
#   'place': '262km NE of Port Mathurin, Mauritius',
#   'timestamp': 1554143945857,
#   'tsunami': 0,
#   'eq_lon': -18.2058,
#   'eq_lat': 65.3656,
#   'city_name': 'quatre cocos',
#   'country_code': 'mu'},
#  {'mag': 6.2,
#   'place': '32km N of Santa Elena, Ecuador',
#   'timestamp': 1554015844795,
#   'tsunami': 0,
#   'eq_lon': -1.9446,
#   'eq_lat': -80.8101,
#   'city_name': 'santa elena',
#   'country_code': 'ec'},
#  {'mag': 6.2,
#   'place': '107km E of Kimbe, Papua New Guinea',
#   'timestamp': 1553944842559,
#   'tsunami': 1,
#   'eq_lon': -5.7003,
#   'eq_lat': 151.1053,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6.2,
#   'place': '265km ESE of Ozernovskiy, Russia',
#   'timestamp': 1553810809401,
#   'tsunami': 0,
#   'eq_lon': 50.4951,
#   'eq_lat': 159.943,
#   'city_name': 'petropavlovsk-kamchatskiy',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': '137km E of Bitung, Indonesia',
#   'timestamp': 1553402255918,
#   'tsunami': 0,
#   'eq_lon': 1.6601,
#   'eq_lat': 126.3955,
#   'city_name': 'bitung',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': '3km WSW of Versalles, Colombia',
#   'timestamp': 1553368877998,
#   'tsunami': 0,
#   'eq_lon': 4.5595,
#   'eq_lat': -76.223,
#   'city_name': 'el dovio',
#   'country_code': 'co'},
#  {'mag': 6.3,
#   'place': '52km E of Luganville, Vanuatu',
#   'timestamp': 1553095438680,
#   'tsunami': 0,
#   'eq_lon': -15.5965,
#   'eq_lat': 167.6551,
#   'city_name': 'luganville',
#   'country_code': 'vu'},
#  {'mag': 6.3,
#   'place': '30km S of Cliza, Bolivia',
#   'timestamp': 1552626230060,
#   'tsunami': 0,
#   'eq_lon': -17.8744,
#   'eq_lat': -65.9072,
#   'city_name': 'cliza',
#   'country_code': 'bo'},
#  {'mag': 6,
#   'place': '139km SSW of Kulumadau, Papua New Guinea',
#   'timestamp': 1552222080607,
#   'tsunami': 0,
#   'eq_lon': -10.1317,
#   'eq_lat': 152.0647,
#   'city_name': 'samarai',
#   'country_code': 'pg'},
#  {'mag': 6.2,
#   'place': '269km SE of Lambasa, Fiji',
#   'timestamp': 1552205546426,
#   'tsunami': 0,
#   'eq_lon': -17.8915,
#   'eq_lat': -178.6034,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6,
#   'place': '40km N of Santa Monica, Philippines',
#   'timestamp': 1552057572620,
#   'tsunami': 0,
#   'eq_lon': 10.384,
#   'eq_lat': 126.006,
#   'city_name': 'sapao',
#   'country_code': 'ph'},
#  {'mag': 6.4,
#   'place': "116km SE of L'Esperance Rock, New Zealand",
#   'timestamp': 1551887174900,
#   'tsunami': 1,
#   'eq_lon': -32.0238,
#   'eq_lat': -177.8845,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 7,
#   'place': '23km NNE of Azangaro, Peru',
#   'timestamp': 1551430242591,
#   'tsunami': 1,
#   'eq_lon': -14.7131,
#   'eq_lat': -70.1546,
#   'city_name': 'azangaro',
#   'country_code': 'pe'},
#  {'mag': 7.5,
#   'place': '111km ESE of Palora, Ecuador',
#   'timestamp': 1550830643770,
#   'tsunami': 1,
#   'eq_lon': -2.1862,
#   'eq_lat': -77.0505,
#   'city_name': 'palora',
#   'country_code': 'ec'},
#  {'mag': 6.4,
#   'place': '49km NW of Namatanai, Papua New Guinea',
#   'timestamp': 1550414155840,
#   'tsunami': 1,
#   'eq_lon': -3.3412,
#   'eq_lat': 152.1319,
#   'city_name': 'namatanai',
#   'country_code': 'pg'},
#  {'mag': 6.2,
#   'place': 'Northern Mid-Atlantic Ridge',
#   'timestamp': 1550174224980,
#   'tsunami': 0,
#   'eq_lon': 35.4267,
#   'eq_lat': -36.0378,
#   'city_name': 'ribeira grande',
#   'country_code': 'pt'},
#  {'mag': 6,
#   'place': '31km NNE of Agrihan, Northern Mariana Islands',
#   'timestamp': 1549974856500,
#   'tsunami': 0,
#   'eq_lon': 19.02,
#   'eq_lat': 145.7965,
#   'city_name': 'airai',
#   'country_code': 'pw'},
#  {'mag': 6,
#   'place': '168km WSW of Sungaipenuh, Indonesia',
#   'timestamp': 1549099656030,
#   'tsunami': 1,
#   'eq_lon': -2.8462,
#   'eq_lat': 100.0743,
#   'city_name': 'sungaipenuh',
#   'country_code': 'id'},
#  {'mag': 6.7,
#   'place': '5km SW of Puerto Madero, Mexico',
#   'timestamp': 1549037652329,
#   'tsunami': 1,
#   'eq_lon': 14.6802,
#   'eq_lat': -92.4527,
#   'city_name': 'puerto madero',
#   'country_code': 'mx'},
#  {'mag': 6.2,
#   'place': '51km SSW of Ndoi Island, Fiji',
#   'timestamp': 1548532604070,
#   'tsunami': 0,
#   'eq_lon': -21.0475,
#   'eq_lat': -178.9592,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.2,
#   'place': '48km SW of Chirovanga, Solomon Islands',
#   'timestamp': 1548474697870,
#   'tsunami': 0,
#   'eq_lon': -7.0089,
#   'eq_lat': 156.3207,
#   'city_name': 'buin',
#   'country_code': 'pg'},
#  {'mag': 6.7,
#   'place': 'Prince Edward Islands region',
#   'timestamp': 1548183703580,
#   'tsunami': 0,
#   'eq_lon': -43.1219,
#   'eq_lat': 42.3568,
#   'city_name': 'margate',
#   'country_code': 'za'},
#  {'mag': 6.3,
#   'place': '80km S of Kahale, Indonesia',
#   'timestamp': 1548133803480,
#   'tsunami': 1,
#   'eq_lon': -10.4148,
#   'eq_lat': 119.0165,
#   'city_name': 'waingapu',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': '66km SSW of Bogorawatu, Indonesia',
#   'timestamp': 1548115163860,
#   'tsunami': 1,
#   'eq_lon': -10.3278,
#   'eq_lat': 119.1521,
#   'city_name': 'waingapu',
#   'country_code': 'id'},
#  {'mag': 6.7,
#   'place': '10km SSW of Coquimbo, Chile',
#   'timestamp': 1547947972480,
#   'tsunami': 1,
#   'eq_lon': -30.0404,
#   'eq_lat': -71.3815,
#   'city_name': 'coquimbo',
#   'country_code': 'cl'},
#  {'mag': 6,
#   'place': '66km NW of Isangel, Vanuatu',
#   'timestamp': 1547817511030,
#   'tsunami': 0,
#   'eq_lon': -19.2036,
#   'eq_lat': 168.7446,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6.2,
#   'place': '165km SW of Lorengau, Papua New Guinea',
#   'timestamp': 1547737595650,
#   'tsunami': 0,
#   'eq_lon': -3.2307,
#   'eq_lat': 146.3889,
#   'city_name': 'lorengau',
#   'country_code': 'pg'},
#  {'mag': 6.6,
#   'place': '94km NW of Sola, Vanuatu',
#   'timestamp': 1547575594300,
#   'tsunami': 1,
#   'eq_lon': -13.336,
#   'eq_lat': 166.8752,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6.3,
#   'place': '16km SSE of Nishinoomote, Japan',
#   'timestamp': 1546951170950,
#   'tsunami': 0,
#   'eq_lon': 30.5872,
#   'eq_lat': 131.0441,
#   'city_name': 'kushima',
#   'country_code': 'jp'},
#  {'mag': 6.6,
#   'place': '151km WNW of Tobelo, Indonesia',
#   'timestamp': 1546795638980,
#   'tsunami': 1,
#   'eq_lon': 2.258,
#   'eq_lat': 126.758,
#   'city_name': 'ternate',
#   'country_code': 'id'},
#  {'mag': 6.8,
#   'place': '90km W of Tarauaca, Brazil',
#   'timestamp': 1546716338520,
#   'tsunami': 0,
#   'eq_lon': -8.144,
#   'eq_lat': -71.587,
#   'city_name': 'tarauaca',
#   'country_code': 'br'},
#  {'mag': 6,
#   'place': '114km SE of Cold Bay, Alaska',
#   'timestamp': 1546223737670,
#   'tsunami': 1,
#   'eq_lon': 54.4266,
#   'eq_lat': -161.5131,
#   'city_name': 'bethel',
#   'country_code': 'us'},
#  {'mag': 7,
#   'place': '96km ESE of Pondaguitan, Philippines',
#   'timestamp': 1546054749740,
#   'tsunami': 1,
#   'eq_lon': 5.8983,
#   'eq_lat': 126.9209,
#   'city_name': 'pundaguitan',
#   'country_code': 'ph'},
#  {'mag': 6.1,
#   'place': "95km W of Nikol'skoye, Russia",
#   'timestamp': 1545655279250,
#   'tsunami': 0,
#   'eq_lon': 55.3439,
#   'eq_lat': 164.5099,
#   'city_name': 'nikolskoye',
#   'country_code': 'ru'},
#  {'mag': 6.4,
#   'place': '92km SW of Pangai, Tonga',
#   'timestamp': 1545606523440,
#   'tsunami': 1,
#   'eq_lon': -20.2855,
#   'eq_lat': -175.071,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6,
#   'place': '95km NW of Sola, Vanuatu',
#   'timestamp': 1545488701180,
#   'tsunami': 0,
#   'eq_lon': -13.4,
#   'eq_lat': 166.8151,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 7.3,
#   'place': "83km W of Nikol'skoye, Russia",
#   'timestamp': 1545325315150,
#   'tsunami': 1,
#   'eq_lon': 55.0999,
#   'eq_lat': 164.6993,
#   'city_name': 'nikolskoye',
#   'country_code': 'ru'},
#  {'mag': 6.3,
#   'place': 'Southeast of Easter Island',
#   'timestamp': 1545183460500,
#   'tsunami': 0,
#   'eq_lon': -36.1378,
#   'eq_lat': -101.0723,
#   'city_name': 'lebu',
#   'country_code': 'cl'},
#  {'mag': 6.1,
#   'place': '147km SSW of Abepura, Indonesia',
#   'timestamp': 1544953357200,
#   'tsunami': 1,
#   'eq_lon': -3.9226,
#   'eq_lat': 140.2323,
#   'city_name': 'vanimo',
#   'country_code': 'pg'},
#  {'mag': 6.3,
#   'place': 'Pacific-Antarctic Ridge',
#   'timestamp': 1544620436180,
#   'tsunami': 0,
#   'eq_lon': -55.6687,
#   'eq_lat': -128.6641,
#   'city_name': 'rikitea',
#   'country_code': 'pf'},
#  {'mag': 7.1,
#   'place': '54km N of Bristol Island, South Sandwich Islands',
#   'timestamp': 1544495189420,
#   'tsunami': 1,
#   'eq_lon': -58.5446,
#   'eq_lat': -26.3856,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.6,
#   'place': '199km ESE of Tadine, New Caledonia',
#   'timestamp': 1543992184130,
#   'tsunami': 1,
#   'eq_lon': -22.0629,
#   'eq_lat': 169.7331,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 7.5,
#   'place': '165km ESE of Tadine, New Caledonia',
#   'timestamp': 1543983488420,
#   'tsunami': 1,
#   'eq_lon': -21.9496,
#   'eq_lat': 169.4266,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.3,
#   'place': '160km ESE of Tadine, New Caledonia',
#   'timestamp': 1543983276490,
#   'tsunami': 0,
#   'eq_lon': -22.0161,
#   'eq_lat': 169.3495,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.4,
#   'place': '294km WNW of Saumlaki, Indonesia',
#   'timestamp': 1543670841080,
#   'tsunami': 1,
#   'eq_lon': -7.3841,
#   'eq_lat': 128.7065,
#   'city_name': 'ambon',
#   'country_code': 'id'},
#  {'mag': 7.1,
#   'place': '14km NNW of Anchorage, Alaska',
#   'timestamp': 1543598969330,
#   'tsunami': 1,
#   'eq_lon': 61.3464,
#   'eq_lat': -149.9552,
#   'city_name': 'anchorage',
#   'country_code': 'us'},
#  {'mag': 6.3,
#   'place': '15km SW of Sarpol-e Zahab, Iran',
#   'timestamp': 1543163852830,
#   'tsunami': 0,
#   'eq_lon': 34.3609,
#   'eq_lat': 45.7443,
#   'city_name': 'mandali',
#   'country_code': 'iq'},
#  {'mag': 6,
#   'place': '36km SE of Mountain, Colombia',
#   'timestamp': 1543117250810,
#   'tsunami': 1,
#   'eq_lon': 13.1817,
#   'eq_lat': -81.0931,
#   'city_name': 'san andres',
#   'country_code': 'co'},
#  {'mag': 6.8,
#   'place': '241km SE of Lambasa, Fiji',
#   'timestamp': 1542572746590,
#   'tsunami': 1,
#   'eq_lon': -17.8735,
#   'eq_lat': -178.9273,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6.2,
#   'place': '136km E of Kirakira, Solomon Islands',
#   'timestamp': 1542338815640,
#   'tsunami': 1,
#   'eq_lon': -10.5383,
#   'eq_lat': 163.1676,
#   'city_name': 'kirakira',
#   'country_code': 'sb'},
#  {'mag': 6.3,
#   'place': 'Southern East Pacific Rise',
#   'timestamp': 1542323341060,
#   'tsunami': 0,
#   'eq_lon': -56.2363,
#   'eq_lat': -122.0441,
#   'city_name': 'rikitea',
#   'country_code': 'pf'},
#  {'mag': 6.4,
#   'place': '101km E of Visokoi Island, South Georgia and the South Sandwich Islands',
#   'timestamp': 1542312142920,
#   'tsunami': 1,
#   'eq_lon': -56.7065,
#   'eq_lat': -25.546,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6.1,
#   'place': "71km SSW of Ust'-Kamchatsk Staryy, Russia",
#   'timestamp': 1542230510870,
#   'tsunami': 0,
#   'eq_lon': 55.6414,
#   'eq_lat': 161.9943,
#   'city_name': 'ust-kamchatsk',
#   'country_code': 'ru'},
#  {'mag': 6.3,
#   'place': 'North Atlantic Ocean',
#   'timestamp': 1541945039560,
#   'tsunami': 0,
#   'eq_lon': 15.5653,
#   'eq_lat': -49.8719,
#   'city_name': 'bathsheba',
#   'country_code': 'bb'},
#  {'mag': 6.1,
#   'place': '80km SSE of Pangai, Tonga',
#   'timestamp': 1541838801140,
#   'tsunami': 0,
#   'eq_lon': -20.4538,
#   'eq_lat': -174.0081,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6.7,
#   'place': '120km NW of Olonkinbyen, Svalbard and Jan Mayen',
#   'timestamp': 1541728180050,
#   'tsunami': 1,
#   'eq_lon': 71.6312,
#   'eq_lat': -11.2431,
#   'city_name': 'husavik',
#   'country_code': 'is'},
#  {'mag': 6,
#   'place': '10km SSE of Sapad, Philippines',
#   'timestamp': 1541318129280,
#   'tsunami': 0,
#   'eq_lon': 7.7599,
#   'eq_lat': 123.867,
#   'city_name': 'imelda',
#   'country_code': 'ph'},
#  {'mag': 6,
#   'place': '202km SW of Vostok, Russia',
#   'timestamp': 1541156475880,
#   'tsunami': 0,
#   'eq_lon': 47.8334,
#   'eq_lat': 146.6972,
#   'city_name': 'vostok',
#   'country_code': 'ru'},
#  {'mag': 6.2,
#   'place': '115km NE of Iquique, Chile',
#   'timestamp': 1541110791690,
#   'tsunami': 0,
#   'eq_lon': -19.5827,
#   'eq_lat': -69.2656,
#   'city_name': 'iquique',
#   'country_code': 'cl'},
#  {'mag': 6.1,
#   'place': '63km ESE of Waitara, New Zealand',
#   'timestamp': 1540865619480,
#   'tsunami': 0,
#   'eq_lon': -39.057,
#   'eq_lat': 174.9584,
#   'city_name': 'piopio',
#   'country_code': 'nz'},
#  {'mag': 6.3,
#   'place': 'Drake Passage',
#   'timestamp': 1540796061250,
#   'tsunami': 0,
#   'eq_lon': -57.434,
#   'eq_lat': -66.3834,
#   'city_name': 'ushuaia',
#   'country_code': 'ar'},
#  {'mag': 6.1,
#   'place': '85km SW of Acajutla, El Salvador',
#   'timestamp': 1540765433420,
#   'tsunami': 0,
#   'eq_lon': 13.0346,
#   'eq_lat': -90.3687,
#   'city_name': 'acajutla',
#   'country_code': 'sv'},
#  {'mag': 6.8,
#   'place': '32km SW of Mouzaki, Greece',
#   'timestamp': 1540508092630,
#   'tsunami': 0,
#   'eq_lon': 37.5203,
#   'eq_lat': 20.5565,
#   'city_name': 'mouzakion',
#   'country_code': 'gr'},
#  {'mag': 6.5,
#   'place': '227km SW of Port Hardy, Canada',
#   'timestamp': 1540189368120,
#   'tsunami': 0,
#   'eq_lon': 49.297,
#   'eq_lat': -129.7237,
#   'city_name': 'port hardy',
#   'country_code': 'ca'},
#  {'mag': 6.8,
#   'place': '202km SW of Port Hardy, Canada',
#   'timestamp': 1540188986450,
#   'tsunami': 1,
#   'eq_lon': 49.3346,
#   'eq_lat': -129.289,
#   'city_name': 'port hardy',
#   'country_code': 'ca'},
#  {'mag': 6.5,
#   'place': '214km SW of Port Hardy, Canada',
#   'timestamp': 1540186779590,
#   'tsunami': 1,
#   'eq_lon': 49.2586,
#   'eq_lat': -129.4124,
#   'city_name': 'port hardy',
#   'country_code': 'ca'},
#  {'mag': 6.5,
#   'place': '170km E of Tadine, New Caledonia',
#   'timestamp': 1539651823580,
#   'tsunami': 1,
#   'eq_lon': -21.7427,
#   'eq_lat': 169.5217,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.3,
#   'place': '170km ESE of Tadine, New Caledonia',
#   'timestamp': 1539649693060,
#   'tsunami': 1,
#   'eq_lon': -21.9232,
#   'eq_lat': 169.4869,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.7,
#   'place': '269km NW of Ozernovskiy, Russia',
#   'timestamp': 1539429022400,
#   'tsunami': 1,
#   'eq_lon': 52.8549,
#   'eq_lat': 153.2429,
#   'city_name': 'oktyabrskiy',
#   'country_code': 'ru'},
#  {'mag': 6.5,
#   'place': "154km S of Severo-Kuril'sk, Russia",
#   'timestamp': 1539213362130,
#   'tsunami': 1,
#   'eq_lon': 49.2902,
#   'eq_lat': 156.2968,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 6.2,
#   'place': '90km SW of Kokopo, Papua New Guinea',
#   'timestamp': 1539208834500,
#   'tsunami': 1,
#   'eq_lon': -4.9624,
#   'eq_lat': 151.7231,
#   'city_name': 'kokopo',
#   'country_code': 'pg'},
#  {'mag': 7,
#   'place': '118km E of Kimbe, Papua New Guinea',
#   'timestamp': 1539204500100,
#   'tsunami': 1,
#   'eq_lon': -5.7012,
#   'eq_lat': 151.2046,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6.1,
#   'place': '135km E of Kimbe, Papua New Guinea',
#   'timestamp': 1539204325300,
#   'tsunami': 1,
#   'eq_lon': -5.7433,
#   'eq_lat': 151.3533,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '40km NNE of Cungapmimbo, Indonesia',
#   'timestamp': 1539197095280,
#   'tsunami': 0,
#   'eq_lon': -7.4525,
#   'eq_lat': 114.4553,
#   'city_name': 'panji',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': "142km S of Severo-Kuril'sk, Russia",
#   'timestamp': 1539071111640,
#   'tsunami': 0,
#   'eq_lon': 49.3959,
#   'eq_lat': 156.2425,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 6,
#   'place': '40km S of Nggongi, Indonesia',
#   'timestamp': 1538438382740,
#   'tsunami': 1,
#   'eq_lon': -10.5585,
#   'eq_lat': 120.2424,
#   'city_name': 'waingapu',
#   'country_code': 'id'},
#  {'mag': 6.7,
#   'place': '262km NNE of Ndoi Island, Fiji',
#   'timestamp': 1538304743010,
#   'tsunami': 1,
#   'eq_lon': -18.3604,
#   'eq_lat': -178.0633,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 7.5,
#   'place': '70km N of Palu, Indonesia',
#   'timestamp': 1538128965250,
#   'tsunami': 1,
#   'eq_lon': -0.2559,
#   'eq_lat': 119.8462,
#   'city_name': 'palu',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': '55km NNW of Palu, Indonesia',
#   'timestamp': 1538117999740,
#   'tsunami': 1,
#   'eq_lon': -0.4009,
#   'eq_lat': 119.7705,
#   'city_name': 'palu',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': 'Southwest Indian Ridge',
#   'timestamp': 1537255661320,
#   'tsunami': 0,
#   'eq_lon': -37.8135,
#   'eq_lat': 49.7765,
#   'city_name': 'taolanaro',
#   'country_code': 'mg'},
#  {'mag': 6.5,
#   'place': 'South of the Fiji Islands',
#   'timestamp': 1537132308820,
#   'tsunami': 0,
#   'eq_lon': -25.415,
#   'eq_lat': 178.1991,
#   'city_name': 'kaeo',
#   'country_code': 'nz'},
#  {'mag': 6.3,
#   'place': '200km WNW of Ile Hunter, New Caledonia',
#   'timestamp': 1536607897420,
#   'tsunami': 1,
#   'eq_lon': -21.988,
#   'eq_lat': 170.1584,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.9,
#   'place': "56km SW of L'Esperance Rock, New Zealand",
#   'timestamp': 1536553142630,
#   'tsunami': 1,
#   'eq_lon': -31.7447,
#   'eq_lat': -179.3728,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.5,
#   'place': '66km NW of Kirakira, Solomon Islands',
#   'timestamp': 1536521495090,
#   'tsunami': 1,
#   'eq_lon': -10.0207,
#   'eq_lat': 161.5025,
#   'city_name': 'kirakira',
#   'country_code': 'sb'},
#  {'mag': 6.2,
#   'place': '7km WNW of Manay, Philippines',
#   'timestamp': 1536391009620,
#   'tsunami': 0,
#   'eq_lon': 7.2377,
#   'eq_lat': 126.4779,
#   'city_name': 'manay',
#   'country_code': 'ph'},
#  {'mag': 6.2,
#   'place': '7km SE of Alausi, Ecuador',
#   'timestamp': 1536286326280,
#   'tsunami': 0,
#   'eq_lon': -2.2532,
#   'eq_lat': -78.7903,
#   'city_name': 'alausi',
#   'country_code': 'ec'},
#  {'mag': 7.9,
#   'place': '102km ESE of Suva, Fiji',
#   'timestamp': 1536248958710,
#   'tsunami': 1,
#   'eq_lon': -18.4743,
#   'eq_lat': 179.3502,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6.6,
#   'place': '27km ENE of Tomakomai, Japan',
#   'timestamp': 1536170879150,
#   'tsunami': 1,
#   'eq_lon': 42.6861,
#   'eq_lat': 141.9294,
#   'city_name': 'chitose',
#   'country_code': 'jp'},
#  {'mag': 7.1,
#   'place': '202km WNW of Ile Hunter, New Caledonia',
#   'timestamp': 1535514716100,
#   'tsunami': 1,
#   'eq_lon': -22.0295,
#   'eq_lat': 170.1262,
#   'city_name': 'tadine',
#   'country_code': 'nc'},
#  {'mag': 6.4,
#   'place': '134km ENE of Anatahan, Northern Mariana Islands',
#   'timestamp': 1535495713410,
#   'tsunami': 1,
#   'eq_lon': 16.8044,
#   'eq_lat': 146.8395,
#   'city_name': 'airai',
#   'country_code': 'pw'},
#  {'mag': 6.2,
#   'place': '94km SE of Kupang, Indonesia',
#   'timestamp': 1535440091360,
#   'tsunami': 1,
#   'eq_lon': -10.773,
#   'eq_lat': 124.1871,
#   'city_name': 'kupang',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': '32km SW of Javanrud, Iran',
#   'timestamp': 1535235205620,
#   'tsunami': 0,
#   'eq_lon': 34.6111,
#   'eq_lat': 46.2422,
#   'city_name': 'javanrud',
#   'country_code': 'ir'},
#  {'mag': 6,
#   'place': '51km SSE of Amukta Island, Alaska',
#   'timestamp': 1535215800767,
#   'tsunami': 0,
#   'eq_lon': 52.0325,
#   'eq_lat': -171.0232,
#   'city_name': 'provideniya',
#   'country_code': 'ru'},
#  {'mag': 7.1,
#   'place': '140km WNW of Iberia, Peru',
#   'timestamp': 1535101448250,
#   'tsunami': 0,
#   'eq_lon': -11.0355,
#   'eq_lat': -70.8284,
#   'city_name': 'iberia',
#   'country_code': 'pe'},
#  {'mag': 6.3,
#   'place': '64km SSE of Tanaga Volcano, Alaska',
#   'timestamp': 1534995312270,
#   'tsunami': 1,
#   'eq_lon': 51.35,
#   'eq_lat': -177.7604,
#   'city_name': 'provideniya',
#   'country_code': 'ru'},
#  {'mag': 6.2,
#   'place': '272km WNW of Bandon, Oregon',
#   'timestamp': 1534930305530,
#   'tsunami': 1,
#   'eq_lon': 43.5637,
#   'eq_lat': -127.7166,
#   'city_name': 'north bend',
#   'country_code': 'us'},
#  {'mag': 6.5,
#   'place': '78km E of Lakatoro, Vanuatu',
#   'timestamp': 1534890746470,
#   'tsunami': 1,
#   'eq_lon': -16.0315,
#   'eq_lat': 168.1428,
#   'city_name': 'lakatoro',
#   'country_code': 'vu'},
#  {'mag': 7.3,
#   'place': '24km ENE of Rio Caribe, Venezuela',
#   'timestamp': 1534887107600,
#   'tsunami': 1,
#   'eq_lon': 10.7731,
#   'eq_lat': -62.9019,
#   'city_name': 'carupano',
#   'country_code': 've'},
#  {'mag': 6.9,
#   'place': '1km S of Belanting, Indonesia',
#   'timestamp': 1534690587490,
#   'tsunami': 1,
#   'eq_lon': -8.319,
#   'eq_lat': 116.6272,
#   'city_name': 'praya',
#   'country_code': 'id'},
#  {'mag': 6.4,
#   'place': '282km ESE of Lambasa, Fiji',
#   'timestamp': 1534652938700,
#   'tsunami': 1,
#   'eq_lon': -16.9783,
#   'eq_lat': -178.0332,
#   'city_name': 'halalo',
#   'country_code': 'wf'},
#  {'mag': 6.3,
#   'place': '4km SW of Belanting, Indonesia',
#   'timestamp': 1534651822640,
#   'tsunami': 1,
#   'eq_lon': -8.3366,
#   'eq_lat': 116.5993,
#   'city_name': 'praya',
#   'country_code': 'id'},
#  {'mag': 6.3,
#   'place': '268km NNE of Ndoi Island, Fiji',
#   'timestamp': 1534638186180,
#   'tsunami': 0,
#   'eq_lon': -18.4447,
#   'eq_lat': -177.6404,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 8.2,
#   'place': '286km NNE of Ndoi Island, Fiji',
#   'timestamp': 1534637980670,
#   'tsunami': 1,
#   'eq_lon': -18.1125,
#   'eq_lat': -178.153,
#   'city_name': 'pangai',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '15km N of Golfito, Costa Rica',
#   'timestamp': 1534548144950,
#   'tsunami': 0,
#   'eq_lon': 8.7791,
#   'eq_lat': -83.1527,
#   'city_name': 'golfito',
#   'country_code': 'cr'},
#  {'mag': 6.5,
#   'place': '114km NNW of Nggilat, Indonesia',
#   'timestamp': 1534520101890,
#   'tsunami': 0,
#   'eq_lon': -7.3718,
#   'eq_lat': 119.8017,
#   'city_name': 'ruteng',
#   'country_code': 'id'},
#  {'mag': 6.3,
#   'place': '251km SE of Iwo Jima, Japan',
#   'timestamp': 1534443773360,
#   'tsunami': 0,
#   'eq_lon': 23.4226,
#   'eq_lat': 143.3187,
#   'city_name': 'shimoda',
#   'country_code': 'jp'},
#  {'mag': 6.5,
#   'place': '51km S of Tanaga Volcano, Alaska',
#   'timestamp': 1534370216310,
#   'tsunami': 1,
#   'eq_lon': 51.4234,
#   'eq_lat': -178.0262,
#   'city_name': 'provideniya',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': '123km NE of Bristol Island, South Sandwich Islands',
#   'timestamp': 1534217392100,
#   'tsunami': 0,
#   'eq_lon': -58.1339,
#   'eq_lat': -25.2725,
#   'city_name': 'chuy',
#   'country_code': 'uy'},
#  {'mag': 6,
#   'place': '73km SSW of Kaktovik, Alaska',
#   'timestamp': 1534108500999,
#   'tsunami': 1,
#   'eq_lon': 69.5227,
#   'eq_lat': -144.3388,
#   'city_name': 'fairbanks',
#   'country_code': 'us'},
#  {'mag': 6.4,
#   'place': '90km SW of Kaktovik, Alaska',
#   'timestamp': 1534085933503,
#   'tsunami': 1,
#   'eq_lon': 69.5762,
#   'eq_lat': -145.291,
#   'city_name': 'fairbanks',
#   'country_code': 'us'},
#  {'mag': 6,
#   'place': "261km SSW of Severo-Kuril'sk, Russia",
#   'timestamp': 1533924727020,
#   'tsunami': 0,
#   'eq_lon': 48.4593,
#   'eq_lat': 154.939,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 6.9,
#   'place': '0km SW of Loloan, Indonesia',
#   'timestamp': 1533469598630,
#   'tsunami': 1,
#   'eq_lon': -8.2581,
#   'eq_lat': 116.4375,
#   'city_name': 'mataram',
#   'country_code': 'id'},
#  {'mag': 6.4,
#   'place': '5km WNW of Obelobel, Indonesia',
#   'timestamp': 1532818058740,
#   'tsunami': 1,
#   'eq_lon': -8.2395,
#   'eq_lat': 116.508,
#   'city_name': 'mataram',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': '150km N of Palue, Indonesia',
#   'timestamp': 1532797643380,
#   'tsunami': 0,
#   'eq_lon': -7.1039,
#   'eq_lat': 122.7263,
#   'city_name': 'maumere',
#   'country_code': 'id'},
#  {'mag': 6,
#   'place': 'Central Mid-Atlantic Ridge',
#   'timestamp': 1532342159590,
#   'tsunami': 0,
#   'eq_lon': -0.2994,
#   'eq_lat': -19.252,
#   'city_name': 'georgetown',
#   'country_code': 'sh'},
#  {'mag': 6,
#   'place': '91km W of Kandrian, Papua New Guinea',
#   'timestamp': 1532025032710,
#   'tsunami': 1,
#   'eq_lon': -6.1139,
#   'eq_lat': 148.7302,
#   'city_name': 'kandrian',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '116km SE of Lata, Solomon Islands',
#   'timestamp': 1531810973020,
#   'tsunami': 0,
#   'eq_lon': -11.5936,
#   'eq_lat': 166.432,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '159km SSE of Sayhut, Yemen',
#   'timestamp': 1531660156470,
#   'tsunami': 0,
#   'eq_lon': 13.8484,
#   'eq_lat': 51.717,
#   'city_name': 'bereda',
#   'country_code': 'so'},
#  {'mag': 6,
#   'place': '137km SSE of Sayhut, Yemen',
#   'timestamp': 1531619839410,
#   'tsunami': 0,
#   'eq_lon': 14.0625,
#   'eq_lat': 51.7365,
#   'city_name': 'bereda',
#   'country_code': 'so'},
#  {'mag': 6.4,
#   'place': '72km NNW of Isangel, Vanuatu',
#   'timestamp': 1531475209070,
#   'tsunami': 0,
#   'eq_lon': -18.9279,
#   'eq_lat': 169.0467,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6,
#   'place': "124km NE of L'Esperance Rock, New Zealand",
#   'timestamp': 1530999229640,
#   'tsunami': 1,
#   'eq_lon': -30.5662,
#   'eq_lat': -178.0701,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.1,
#   'place': '91km E of Ozernovskiy, Russia',
#   'timestamp': 1530841204610,
#   'tsunami': 0,
#   'eq_lon': 51.4994,
#   'eq_lat': 157.8404,
#   'city_name': 'ozernovskiy',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': '28km WSW of Port-Vila, Vanuatu',
#   'timestamp': 1529615612660,
#   'tsunami': 0,
#   'eq_lon': -17.7905,
#   'eq_lat': 168.0568,
#   'city_name': 'vila',
#   'country_code': 'vu'},
#  {'mag': 6.1,
#   'place': 'South of the Kermadec Islands',
#   'timestamp': 1526607931460,
#   'tsunami': 0,
#   'eq_lon': -34.5886,
#   'eq_lat': -178.4143,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.2,
#   'place': '36km NW of Ishkashim, Tajikistan',
#   'timestamp': 1525862505910,
#   'tsunami': 0,
#   'eq_lon': 36.9942,
#   'eq_lat': 71.3822,
#   'city_name': 'eskasem',
#   'country_code': 'af'},
#  {'mag': 6,
#   'place': '177km SSW of Kokopo, Papua New Guinea',
#   'timestamp': 1525852674950,
#   'tsunami': 1,
#   'eq_lon': -5.8822,
#   'eq_lat': 151.7836,
#   'city_name': 'kokopo',
#   'country_code': 'pg'},
#  {'mag': 6.1,
#   'place': '64km NNW of Pandan, Philippines',
#   'timestamp': 1525501145040,
#   'tsunami': 0,
#   'eq_lon': 14.5708,
#   'eq_lat': 123.9192,
#   'city_name': 'pandan',
#   'country_code': 'ph'},
#  {'mag': 6.9,
#   'place': '19km SSW of Leilani Estates, Hawaii',
#   'timestamp': 1525473174650,
#   'tsunami': 1,
#   'eq_lon': 19.3181667,
#   'eq_lat': -154.9996667,
#   'city_name': 'hilo',
#   'country_code': 'us'},
#  {'mag': 6,
#   'place': 'Easter Island region',
#   'timestamp': 1525242769020,
#   'tsunami': 0,
#   'eq_lon': -24.2723,
#   'eq_lat': -111.6328,
#   'city_name': 'rikitea',
#   'country_code': 'pf'},
#  {'mag': 6,
#   'place': 'Prince Edward Islands region',
#   'timestamp': 1524172157000,
#   'tsunami': 0,
#   'eq_lon': -42.7797,
#   'eq_lat': 42.1877,
#   'city_name': 'margate',
#   'country_code': 'za'},
#  {'mag': 6,
#   'place': '88km NW of Kota Ternate, Indonesia',
#   'timestamp': 1523820643200,
#   'tsunami': 0,
#   'eq_lon': 1.4083,
#   'eq_lat': 126.8759,
#   'city_name': 'ternate',
#   'country_code': 'id'},
#  {'mag': 6.2,
#   'place': '56km SSW of Ovalle, Chile',
#   'timestamp': 1523355574370,
#   'tsunami': 0,
#   'eq_lon': -31.0258,
#   'eq_lat': -71.5292,
#   'city_name': 'ovalle',
#   'country_code': 'cl'},
#  {'mag': 6.3,
#   'place': '84km WSW of Porgera, Papua New Guinea',
#   'timestamp': 1523080120010,
#   'tsunami': 1,
#   'eq_lon': -5.8382,
#   'eq_lat': 142.5314,
#   'city_name': 'tari',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '43km ESE of Tarragona, Philippines',
#   'timestamp': 1522900418410,
#   'tsunami': 0,
#   'eq_lon': 6.8325,
#   'eq_lat': 126.7785,
#   'city_name': 'tarragona',
#   'country_code': 'ph'},
#  {'mag': 6.8,
#   'place': '11km NNE of Carandayti, Bolivia',
#   'timestamp': 1522676434840,
#   'tsunami': 0,
#   'eq_lon': -20.6588,
#   'eq_lat': -63.0058,
#   'city_name': 'boyuibe',
#   'country_code': 'bo'},
#  {'mag': 6.1,
#   'place': 'South of the Fiji Islands',
#   'timestamp': 1522648655680,
#   'tsunami': 0,
#   'eq_lon': -24.719,
#   'eq_lat': -176.8865,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.9,
#   'place': '150km E of Kimbe, Papua New Guinea',
#   'timestamp': 1522358736790,
#   'tsunami': 1,
#   'eq_lon': -5.5321,
#   'eq_lat': 151.4999,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6.7,
#   'place': '139km E of Kimbe, Papua New Guinea',
#   'timestamp': 1522057860430,
#   'tsunami': 1,
#   'eq_lon': -5.5024,
#   'eq_lat': 151.4025,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6.4,
# ...
#   'tsunami': 0,
#   'eq_lon': -28.681,
#   'eq_lat': -178.916,
#   'city_name': 'vaini',
#   'country_code': 'to'},
#  {'mag': 6.5,
#   'place': '31km N of Rabaul, Papua New Guinea',
#   'timestamp': 1366758880630,
#   'tsunami': 1,
#   'eq_lon': -3.898,
#   'eq_lat': 152.127,
#   'city_name': 'rabaul',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '20km NNW of La Union, Mexico',
#   'timestamp': 1366593392840,
#   'tsunami': 0,
#   'eq_lon': 18.081,
#   'eq_lat': -102.182,
#   'city_name': 'las guacamayas',
#   'country_code': 'mx'},
#  {'mag': 6.1,
#   'place': 'Izu Islands, Japan region',
#   'timestamp': 1366514536220,
#   'tsunami': 0,
#   'eq_lon': 29.933,
#   'eq_lat': 138.887,
#   'city_name': 'oyama',
#   'country_code': 'jp'},
#  {'mag': 6.1,
#   'place': "97km SE of Severo-Kuril'sk, Russia",
#   'timestamp': 1366463570510,
#   'tsunami': 0,
#   'eq_lon': 50.099,
#   'eq_lat': 157.148,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 6.6,
#   'place': '56km WSW of Linqiong, China',
#   'timestamp': 1366416167540,
#   'tsunami': 0,
#   'eq_lon': 30.308,
#   'eq_lat': 102.888,
#   'city_name': 'yaan',
#   'country_code': 'cn'},
#  {'mag': 6.1,
#   'place': "135km SE of Severo-Kuril'sk, Russia",
#   'timestamp': 1366401520250,
#   'tsunami': 0,
#   'eq_lon': 49.965,
#   'eq_lat': 157.652,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 7.2,
#   'place': "251km ENE of Kuril'sk, Russia",
#   'timestamp': 1366340752650,
#   'tsunami': 1,
#   'eq_lon': 46.221,
#   'eq_lat': 150.788,
#   'city_name': 'sentyabrskiy',
#   'country_code': 'ru'},
#  {'mag': 6.6,
#   'place': '23km ESE of Aitape, Papua New Guinea',
#   'timestamp': 1366152926680,
#   'tsunami': 1,
#   'eq_lon': -3.214,
#   'eq_lat': 142.542,
#   'city_name': 'aitape',
#   'country_code': 'pg'},
#  {'mag': 7.7,
#   'place': '83km E of Khash, Iran',
#   'timestamp': 1366109060180,
#   'tsunami': 0,
#   'eq_lon': 28.033,
#   'eq_lat': 61.996,
#   'city_name': 'khash',
#   'country_code': 'ir'},
#  {'mag': 6.6,
#   'place': '98km W of Panguna, Papua New Guinea',
#   'timestamp': 1365903142640,
#   'tsunami': 1,
#   'eq_lon': -6.475,
#   'eq_lat': 154.607,
#   'city_name': 'panguna',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': '53km NNE of Isangel, Vanuatu',
#   'timestamp': 1365893390550,
#   'tsunami': 0,
#   'eq_lon': -19.141,
#   'eq_lat': 169.535,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6.4,
#   'place': '89km SE of Bandar Bushehr, Iran',
#   'timestamp': 1365508369920,
#   'tsunami': 0,
#   'eq_lon': 28.428,
#   'eq_lat': 51.593,
#   'city_name': 'khormuj',
#   'country_code': 'ir'},
#  {'mag': 7,
#   'place': '240km E of Enarotali, Indonesia',
#   'timestamp': 1365223355860,
#   'tsunami': 1,
#   'eq_lon': -3.517,
#   'eq_lat': 138.476,
#   'city_name': 'vanimo',
#   'country_code': 'pg'},
#  {'mag': 6.3,
#   'place': '9km N of Zarubino, Russia',
#   'timestamp': 1365166802130,
#   'tsunami': 0,
#   'eq_lon': 42.736,
#   'eq_lat': 131.003,
#   'city_name': 'zarubino',
#   'country_code': 'ru'},
#  {'mag': 6,
#   'place': '108km E of Miyako, Japan',
#   'timestamp': 1364842397420,
#   'tsunami': 0,
#   'eq_lon': 39.526,
#   'eq_lat': 143.167,
#   'city_name': 'yamada',
#   'country_code': 'jp'},
#  {'mag': 6.2,
#   'place': '6km ENE of Santa Catarina Pinula, Guatemala',
#   'timestamp': 1364252532770,
#   'tsunami': 0,
#   'eq_lon': 14.487,
#   'eq_lat': -90.463,
#   'city_name': 'fraijanes',
#   'country_code': 'gt'},
#  {'mag': 6.1,
#   'place': '167km NW of Ceva-i-Ra, Fiji',
#   'timestamp': 1364112825130,
#   'tsunami': 0,
#   'eq_lon': -20.757,
#   'eq_lat': 173.37,
#   'city_name': 'isangel',
#   'country_code': 'vu'},
#  {'mag': 6.5,
#   'place': '32km E of Finschhafen, Papua New Guinea',
#   'timestamp': 1362955910800,
#   'tsunami': 1,
#   'eq_lon': -6.598,
#   'eq_lat': 148.174,
#   'city_name': 'finschhafen',
#   'country_code': 'pg'},
#  {'mag': 6.5,
#   'place': '89km SE of Ozernovskiy, Russia',
#   'timestamp': 1362144049930,
#   'tsunami': 0,
#   'eq_lon': 50.958,
#   'eq_lat': 157.408,
#   'city_name': 'ozernovskiy',
#   'country_code': 'ru'},
#  {'mag': 6.4,
#   'place': '93km SE of Ozernovskiy, Russia',
#   'timestamp': 1362142431070,
#   'tsunami': 1,
#   'eq_lon': 50.895,
#   'eq_lat': 157.453,
#   'city_name': 'ozernovskiy',
#   'country_code': 'ru'},
#  {'mag': 6.9,
#   'place': '84km SE of Ozernovskiy, Russia',
#   'timestamp': 1362060350250,
#   'tsunami': 1,
#   'eq_lon': 50.954,
#   'eq_lat': 157.283,
#   'city_name': 'ozernovskiy',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': '23km ESE of Suncho Corral, Argentina',
#   'timestamp': 1361534518200,
#   'tsunami': 0,
#   'eq_lon': -27.932,
#   'eq_lat': -63.097,
#   'city_name': 'santiago del estero',
#   'country_code': 'ar'},
#  {'mag': 6.1,
#   'place': '16km SE of Caburan, Philippines',
#   'timestamp': 1360989456220,
#   'tsunami': 0,
#   'eq_lon': 5.812,
#   'eq_lat': 125.748,
#   'city_name': 'culaman',
#   'country_code': 'ph'},
#  {'mag': 6.6,
#   'place': '135km WSW of Druzhina, Russia',
#   'timestamp': 1360847633130,
#   'tsunami': 1,
#   'eq_lon': 67.631,
#   'eq_lat': 142.508,
#   'city_name': 'khonuu',
#   'country_code': 'ru'},
#  {'mag': 6,
#   'place': '48km WSW of Lata, Solomon Islands',
#   'timestamp': 1360521572140,
#   'tsunami': 0,
#   'eq_lon': -10.94,
#   'eq_lat': 165.461,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.6,
#   'place': '25km S of Lata, Solomon Islands',
#   'timestamp': 1360443742790,
#   'tsunami': 1,
#   'eq_lon': -10.994,
#   'eq_lat': 165.741,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.9,
#   'place': '2km N of Yacuanquer, Colombia',
#   'timestamp': 1360419367880,
#   'tsunami': 1,
#   'eq_lon': 1.135,
#   'eq_lat': -77.393,
#   'city_name': 'yacuanquer',
#   'country_code': 'co'},
#  {'mag': 7.1,
#   'place': '31km SE of Lata, Solomon Islands',
#   'timestamp': 1360337198470,
#   'tsunami': 1,
#   'eq_lon': -10.928,
#   'eq_lat': 166.018,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.8,
#   'place': '21km SSE of Lata, Solomon Islands',
#   'timestamp': 1360321931510,
#   'tsunami': 1,
#   'eq_lon': -10.838,
#   'eq_lat': 165.969,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.7,
#   'place': '36km SSW of Lata, Solomon Islands',
#   'timestamp': 1360263556270,
#   'tsunami': 1,
#   'eq_lon': -10.997,
#   'eq_lat': 165.655,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '142km SW of Lata, Solomon Islands',
#   'timestamp': 1360197010790,
#   'tsunami': 0,
#   'eq_lon': -11.658,
#   'eq_lat': 164.94,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '59km S of Lata, Solomon Islands',
#   'timestamp': 1360151635190,
#   'tsunami': 0,
#   'eq_lon': -11.243,
#   'eq_lat': 165.728,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '117km W of Lata, Solomon Islands',
#   'timestamp': 1360146797460,
#   'tsunami': 0,
#   'eq_lon': -10.642,
#   'eq_lat': 164.765,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.1,
#   'place': '144km W of Lata, Solomon Islands',
#   'timestamp': 1360132519250,
#   'tsunami': 0,
#   'eq_lon': -10.791,
#   'eq_lat': 164.551,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 7,
#   'place': '27km NNW of Lata, Solomon Islands',
#   'timestamp': 1360115654610,
#   'tsunami': 0,
#   'eq_lon': -10.499,
#   'eq_lat': 165.588,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 7.1,
#   'place': '114km WSW of Lata, Solomon Islands',
#   'timestamp': 1360113799760,
#   'tsunami': 0,
#   'eq_lon': -11.183,
#   'eq_lat': 164.882,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 8,
#   'place': '76km W of Lata, Solomon Islands',
#   'timestamp': 1360113145830,
#   'tsunami': 1,
#   'eq_lon': -10.799,
#   'eq_lat': 165.114,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '66km WSW of Lata, Solomon Islands',
#   'timestamp': 1360109242100,
#   'tsunami': 0,
#   'eq_lon': -10.864,
#   'eq_lat': 165.248,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '67km WSW of Lata, Solomon Islands',
#   'timestamp': 1359831486480,
#   'tsunami': 0,
#   'eq_lon': -10.887,
#   'eq_lat': 165.284,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.9,
#   'place': '19km SSW of Obihiro, Japan',
#   'timestamp': 1359814655130,
#   'tsunami': 0,
#   'eq_lon': 42.77,
#   'eq_lat': 143.092,
#   'city_name': 'obihiro',
#   'country_code': 'jp'},
#  {'mag': 6.4,
#   'place': '66km SW of Lata, Solomon Islands',
#   'timestamp': 1359757113070,
#   'tsunami': 0,
#   'eq_lon': -11.12,
#   'eq_lat': 165.378,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.3,
#   'place': '53km WSW of Lata, Solomon Islands',
#   'timestamp': 1359756994170,
#   'tsunami': 0,
#   'eq_lon': -10.896,
#   'eq_lat': 165.379,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6,
#   'place': '53km SW of Lata, Solomon Islands',
#   'timestamp': 1359697001790,
#   'tsunami': 0,
#   'eq_lon': -11.104,
#   'eq_lat': 165.532,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.1,
#   'place': '60km E of Lata, Solomon Islands',
#   'timestamp': 1359603223720,
#   'tsunami': 0,
#   'eq_lon': -10.64,
#   'eq_lat': 166.367,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.1,
#   'place': '59km E of Lata, Solomon Islands',
#   'timestamp': 1359587023660,
#   'tsunami': 0,
#   'eq_lon': -10.634,
#   'eq_lat': 166.372,
#   'city_name': 'lata',
#   'country_code': 'sb'},
#  {'mag': 6.8,
#   'place': '56km NNE of Vallenar, Chile',
#   'timestamp': 1359576943340,
#   'tsunami': 0,
#   'eq_lon': -28.094,
#   'eq_lat': -70.653,
#   'city_name': 'vallenar',
#   'country_code': 'cl'},
#  {'mag': 6.1,
#   'place': '60km SE of Kegen, Kazakhstan',
#   'timestamp': 1359391133580,
#   'tsunami': 0,
#   'eq_lon': 42.605,
#   'eq_lat': 79.708,
#   'city_name': 'karakol',
#   'country_code': 'kg'},
#  {'mag': 6.1,
#   'place': '47km SSW of Sigli, Indonesia',
#   'timestamp': 1358806972760,
#   'tsunami': 1,
#   'eq_lon': 4.927,
#   'eq_lat': 95.907,
#   'city_name': 'sigli',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': 'Pacific-Antarctic Ridge',
#   'timestamp': 1358266177080,
#   'tsunami': 0,
#   'eq_lon': -62.571,
#   'eq_lat': -161.432,
#   'city_name': 'mataura',
#   'country_code': 'pf'},
#  {'mag': 7.5,
#   'place': 'Southeastern Alaska',
#   'timestamp': 1357376294957,
#   'tsunami': 0,
#   'eq_lon': 55.228,
#   'eq_lat': -134.8591,
#   'city_name': 'sitka',
#   'country_code': 'us'},
#  {'mag': 6.7,
#   'place': 'Vanuatu',
#   'timestamp': 1356128888570,
#   'tsunami': 0,
#   'eq_lon': -14.344,
#   'eq_lat': 167.286,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6.1,
#   'place': 'Sulawesi, Indonesia',
#   'timestamp': 1355735790900,
#   'tsunami': 0,
#   'eq_lon': -0.649,
#   'eq_lat': 123.807,
#   'city_name': 'luwuk',
#   'country_code': 'id'},
#  {'mag': 6.1,
#   'place': 'New Ireland region, Papua New Guinea',
#   'timestamp': 1355599802170,
#   'tsunami': 0,
#   'eq_lon': -4.632,
#   'eq_lat': 153.016,
#   'city_name': 'kokopo',
#   'country_code': 'pg'},
#  {'mag': 6,
#   'place': 'Near Islands, Aleutian Islands, Alaska',
#   'timestamp': 1355546969650,
#   'tsunami': 0,
#   'eq_lon': 52.291,
#   'eq_lat': 174.011,
#   'city_name': 'nikolskoye',
#   'country_code': 'ru'},
#  {'mag': 6.3,
#   'place': 'off the west coast of Baja California',
#   'timestamp': 1355481361590,
#   'tsunami': 0,
#   'eq_lon': 31.095,
#   'eq_lat': -119.66,
#   'city_name': 'rosarito',
#   'country_code': 'mx'},
#  {'mag': 6,
#   'place': 'Molucca Sea',
#   'timestamp': 1355206707330,
#   'tsunami': 0,
#   'eq_lon': 0.533,
#   'eq_lat': 126.231,
#   'city_name': 'ternate',
#   'country_code': 'id'},
#  {'mag': 7.1,
#   'place': 'Banda Sea',
#   'timestamp': 1355158388770,
#   'tsunami': 0,
#   'eq_lon': -6.533,
#   'eq_lat': 129.825,
#   'city_name': 'tual',
#   'country_code': 'id'},
#  {'mag': 6.3,
#   'place': 'North Island of New Zealand',
#   'timestamp': 1354904346310,
#   'tsunami': 0,
#   'eq_lon': -38.428,
#   'eq_lat': 176.067,
#   'city_name': 'taupo',
#   'country_code': 'nz'},
#  {'mag': 6.2,
#   'place': 'off the east coast of Honshu, Japan',
#   'timestamp': 1354869074800,
#   'tsunami': 0,
#   'eq_lon': 37.914,
#   'eq_lat': 143.764,
#   'city_name': 'kamaishi',
#   'country_code': 'jp'},
#  {'mag': 7.3,
#   'place': 'off the east coast of Honshu, Japan',
#   'timestamp': 1354868303130,
#   'tsunami': 0,
#   'eq_lon': 37.89,
#   'eq_lat': 143.949,
#   'city_name': 'kamaishi',
#   'country_code': 'jp'},
#  {'mag': 6.1,
#   'place': 'Vanuatu',
#   'timestamp': 1354409662690,
#   'tsunami': 0,
#   'eq_lon': -16.975,
#   'eq_lat': 167.645,
#   'city_name': 'lakatoro',
#   'country_code': 'vu'},
#  {'mag': 6,
#   'place': 'New Britain region, Papua New Guinea',
#   'timestamp': 1353318274120,
#   'tsunami': 0,
#   'eq_lon': -5.705,
#   'eq_lat': 151.602,
#   'city_name': 'kimbe',
#   'country_code': 'pg'},
#  {'mag': 6.5,
#   'place': 'Kuril Islands',
#   'timestamp': 1353089559910,
#   'tsunami': 0,
#   'eq_lon': 49.28,
#   'eq_lat': 155.425,
#   'city_name': 'severo-kurilsk',
#   'country_code': 'ru'},
#  {'mag': 6.1,
#   'place': 'Guerrero, Mexico',
#   'timestamp': 1352971221910,
#   'tsunami': 0,
#   'eq_lon': 18.346,
#   'eq_lat': -100.382,
#   'city_name': 'tlalchapa',
#   'country_code': 'mx'},
#  {'mag': 6.1,
#   'place': 'Coquimbo, Chile',
#   'timestamp': 1352919726120,
#   'tsunami': 0,
#   'eq_lon': -29.118,
#   'eq_lat': -71.19,
#   'city_name': 'vallenar',
#   'country_code': 'cl'},
#  {'mag': 6.1,
#   'place': 'off the coast of Aisen, Chile',
#   'timestamp': 1352781086760,
#   'tsunami': 0,
#   'eq_lon': -45.761,
#   'eq_lat': -77.053,
#   'city_name': 'castro',
#   'country_code': 'cl'},
#  {'mag': 6.3,
#   'place': 'Gulf of Alaska',
#   'timestamp': 1352752934620,
#   'tsunami': 0,
#   'eq_lon': 57.792,
#   'eq_lat': -142.855,
#   'city_name': 'haines junction',
#   'country_code': 'ca'},
#  {'mag': 6.5,
#   'place': 'offshore Guatemala',
#   'timestamp': 1352672099240,
#   'tsunami': 0,
#   'eq_lon': 14.129,
#   'eq_lat': -92.164,
#   'city_name': 'champerico',
#   'country_code': 'gt'},
#  {'mag': 6.8,
#   'place': 'Myanmar',
#   'timestamp': 1352596358870,
#   'tsunami': 0,
#   'eq_lon': 23.005,
#   'eq_lat': 95.885,
#   'city_name': 'shwebo',
#   'country_code': 'mm'},
#  {'mag': 6,
#   'place': 'central Peru',
#   'timestamp': 1352559470740,
#   'tsunami': 0,
#   'eq_lon': -8.866,
#   'eq_lat': -75.071,
#   'city_name': 'campoverde',
#   'country_code': 'pe'},
#  {'mag': 6.1,
#   'place': 'Vancouver Island, Canada region',
#   'timestamp': 1352340110630,
#   'tsunami': 0,
#   'eq_lon': 49.231,
#   'eq_lat': -128.477,
#   'city_name': 'port hardy',
#   'country_code': 'ca'},
#  {'mag': 7.4,
#   'place': 'offshore Guatemala',
#   'timestamp': 1352306146930,
#   'tsunami': 0,
#   'eq_lon': 13.988,
#   'eq_lat': -91.895,
#   'city_name': 'champerico',
#   'country_code': 'gt'},
#  {'mag': 6.1,
#   'place': 'Mindanao, Philippines',
#   'timestamp': 1351880252730,
#   'tsunami': 0,
#   'eq_lon': 9.219,
#   'eq_lat': 126.161,
#   'city_name': 'tigao',
#   'country_code': 'ph'},
#  {'mag': 6.2,
#   'place': 'Haida Gwaii, Canada',
#   'timestamp': 1351565342270,
#   'tsunami': 0,
#   'eq_lon': 52.365,
#   'eq_lat': -131.902,
#   'city_name': 'prince rupert',
#   'country_code': 'ca'},
#  {'mag': 6.3,
#   'place': 'Haida Gwaii, Canada',
#   'timestamp': 1351450460830,
#   'tsunami': 0,
#   'eq_lon': 52.674,
#   'eq_lat': -132.602,
#   'city_name': 'prince rupert',
#   'country_code': 'ca'},
#  {'mag': 7.8,
#   'place': 'Haida Gwaii, Canada',
#   'timestamp': 1351393448820,
#   'tsunami': 0,
#   'eq_lon': 52.788,
#   'eq_lat': -132.101,
#   'city_name': 'prince rupert',
#   'country_code': 'ca'},
#  {'mag': 6.5,
#   'place': 'Costa Rica',
#   'timestamp': 1351039532990,
#   'tsunami': 0,
#   'eq_lon': 10.086,
#   'eq_lat': -85.298,
#   'city_name': 'nicoya',
#   'country_code': 'cr'},
#  {'mag': 6.2,
#   'place': 'Vanuatu',
#   'timestamp': 1350774032450,
#   'tsunami': 0,
#   'eq_lon': -13.552,
#   'eq_lat': 166.564,
#   'city_name': 'sola',
#   'country_code': 'vu'},
#  {'mag': 6,
#   'place': 'Celebes Sea',
#   'timestamp': 1350448950400,
#   'tsunami': 0,
#   'eq_lon': 4.232,
#   'eq_lat': 124.52,
#   'city_name': 'sarangani',
#   'country_code': 'ph'},
#  {'mag': 6.6,
#   'place': 'near the south coast of Papua, Indonesia',
#   'timestamp': 1350001888270,
#   'tsunami': 0,
#   'eq_lon': -4.892,
#   'eq_lat': 134.03,
#   'city_name': 'tual',
#   'country_code': 'id'},
#  {'mag': 6.6,
#   'place': 'west of Macquarie Island',
#   'timestamp': 1349785929770,
#   'tsunami': 0,
#   'eq_lon': -60.326,
#   'eq_lat': 153.699,
#   'city_name': 'hobart',
#   'country_code': 'au'},
#  {'mag': 6.1,
#   'place': 'Banda Sea',
#   'timestamp': 1349696611420,
#   'tsunami': 0,
#   'eq_lon': -4.472,
#   'eq_lat': 129.129,
#   'city_name': 'amahai',
#   'country_code': 'id'},
#  ...]

# %%
# Create df from list of dictionaries
earthquakes_df_final = pd.DataFrame(allearthquake_features)

# Preview df
earthquakes_df_final
# Out:
#        mag                                    place      timestamp  tsunami  \
# 0      6.0              41km NW of Platanos, Greece  1574839422552        0
# 1      6.4         16km WNW of Fushe-Kruje, Albania  1574736852598        0
# 2      6.3                  96km SE of Adak, Alaska  1574556841052        1
# 3      6.1                  Papua region, Indonesia  1574511076261        1
# 4      6.2  32km ESE of Chaloem Phra Kiat, Thailand  1574293843955        0
# ...    ...                                      ...            ...      ...
# 11616  6.5                    Hawaii region, Hawaii -4062404700000        0
# 11617  6.1                    Hawaii region, Hawaii -4099680000000        0
# 11618  6.1                    Hawaii region, Hawaii -4135624200000        0
# 11619  6.8       San Francisco Bay area, California -4214709000000        0
# 11620  7.0                    Hawaii region, Hawaii -4625739000000        0
#
#         eq_lon    eq_lat     city_name country_code
# 0      35.7272   23.2673      platanos           gr
# 1      41.5109   19.5218        shijak           al
# 2      51.3809 -175.5108   provideniya           ru
# 3       1.6286  132.7854     manokwari           id
# 4      19.4533  101.3558  chiang klang           th
# ...        ...       ...           ...          ...
# 11616  19.2500 -155.0000          hilo           us
# 11617  19.2500 -155.0000          hilo           us
# 11618  19.2500 -155.0000          hilo           us
# 11619  37.8000 -122.2000      piedmont           us
# 11620  19.2500 -155.0000          hilo           us
#
# [11621 rows x 8 columns]

# %%
# Connect to local database
engine = create_engine(f"postgresql://postgres:{key}@localhost:5432/earthquakes_db")

# Check for tables
engine.table_names()
# Out:
# ['earthquakes', 'population_size', 'gdp']

# %%
# Load df into the database
earthquakes_df_final.to_sql(name='earthquakes',con=engine,if_exists='append',index=False)

# %%
# Confirm data has been added by querying the gdp table
earthquake_df_from_sql = pd.read_sql_query('SELECT * FROM earthquakes',con=engine)
earthquake_df_from_sql
# Out:
#        mag                                    place      timestamp  tsunami  \
# 0      6.0              41km NW of Platanos, Greece  1574839422552      0.0
# 1      6.4         16km WNW of Fushe-Kruje, Albania  1574736852598      0.0
# 2      6.3                  96km SE of Adak, Alaska  1574556841052      1.0
# 3      6.1                  Papua region, Indonesia  1574511076261      1.0
# 4      6.2  32km ESE of Chaloem Phra Kiat, Thailand  1574293843955      0.0
# ...    ...                                      ...            ...      ...
# 11616  6.5                    Hawaii region, Hawaii -4062404700000      0.0
# 11617  6.1                    Hawaii region, Hawaii -4099680000000      0.0
# 11618  6.1                    Hawaii region, Hawaii -4135624200000      0.0
# 11619  6.8       San Francisco Bay area, California -4214709000000      0.0
# 11620  7.0                    Hawaii region, Hawaii -4625739000000      0.0
#
#          eq_lat   eq_lon     city_name country_code
# 0       23.2673  35.7272      platanos           gr
# 1       19.5218  41.5109        shijak           al
# 2     -175.5108  51.3809   provideniya           ru
# 3      132.7854   1.6286     manokwari           id
# 4      101.3558  19.4533  chiang klang           th
# ...         ...      ...           ...          ...
# 11616 -155.0000  19.2500          hilo           us
# 11617 -155.0000  19.2500          hilo           us
# 11618 -155.0000  19.2500          hilo           us
# 11619 -122.2000  37.8000      piedmont           us
# 11620 -155.0000  19.2500          hilo           us
#
# [11621 rows x 8 columns]
